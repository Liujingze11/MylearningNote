# %% [markdown]
# AI Agent教学

# %%
# 定义llm
from langchain.chat_models import ChatOpenAI

llm = ChatOpenAI(
    temperature=0,
    openai_api_key="sk-这里填你的DeepSeek_API_KEY",
    openai_api_base="https://api.deepseek.com",
    model="deepseek-chat",
)

# %% [markdown]
# 搭建工具
# - serpai是一个菊科

# %%
! pip install google-search-results
! pip install numexpr

# %%
import os

# 直接在代码里设置 API Key（原Key已替换为占位文字）
os.environ["SERPAPI_API_KEY"] = "这里填你的SERPAPI_API_KEY"

# %%
from langchain.agents import load_tools

tools = load_tools(["serpapi", "llm-math"], llm=llm)

# %% [markdown]
# 定义agent，使用小样本增强生成类型

# %%
from langchain.agents import initialize_agent
from langchain.agents import AgentType

agent = initialize_agent(
    tools,          # 刚才加载的工具列表
    llm,            # 大语言模型
    agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,  # Agent类型（零样本推理）
    verbose=True    # 是否显示详细日志，调试用
)
# Out:
# /var/folders/nj/99yjcb655z357nr6lrkngz640000gn/T/ipykernel_16622/4139301731.py:4: LangChainDeprecationWarning: LangChain agents will continue to be supported, but it is recommended for new use cases to be built with LangGraph. LangGraph offers a more flexible and full-featured framework for building agents, including support for tool-calling, persistence of state, and human-in-the-loop workflows. For details, refer to the `LangGraph documentation <https://langchain-ai.github.io/langgraph/>`_ as well as guides for `Migrating from AgentExecutor <https://python.langchain.com/docs/how_to/migrate_agent/>`_ and LangGraph's `Pre-built ReAct agent <https://langchain-ai.github.io/langgraph/how-tos/create-react-agent/>`_.
#   agent = initialize_agent(

# %%
agent.run("中国人的平均体重是多少？帮我算一下它的平方？")
